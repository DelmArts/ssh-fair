# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import requests as r
import rdflib
from tqdm import tqdm

tqdm.pandas()

# %% [markdown]
# ## Dumping DANS

# %% [markdown]
# First, we use the `pyDataverse` library to connect to the DANS repository (it's a dataverse repository)
#
# https://pydataverse.readthedocs.io/en/latest/user/basic-usage.html#connect-to-native-api

# %%
from pyDataverse.api import NativeApi
api = NativeApi("https://ssh.datastations.nl/")

api.get_info_version().json()
# Out:
# {'status': 'OK',
#  'data': {'version': '6.5', 'build': 'DANS-DataStation-PATCH-7'}}

# %% [markdown]
# We dump the entire repository by getting the contents of the special dataverse `:root`. Warning: this takes like 15 mins.

# %%
try:
    with open("dans.json", "rb") as f:
        dans = json.load(f)

except FileNotFoundError:
    tree = api.get_dataverse_contents(":root")

    dans = tree.json()

    with open("dans.json", "wb") as f:
        f.write(tree.read())

# %% [markdown]
# Move the data into pandas to start working with it:

# %%
df_dans = pd.DataFrame.from_dict(dans["data"])

df_dans
# Out:
#           id     identifier                           persistentUrl protocol  \
# 0       1920  dans-zhr-eswk  https://doi.org/10.17026/dans-zhr-eswk      doi
# 1       1921  dans-xeh-f6xm  https://doi.org/10.17026/dans-xeh-f6xm      doi
# 2       1924  dans-zct-en83  https://doi.org/10.17026/dans-zct-en83      doi
# 3       1949  dans-xjk-kqxa  https://doi.org/10.17026/dans-xjk-kqxa      doi
# 4       2082  dans-xpa-uek9  https://doi.org/10.17026/dans-xpa-uek9      doi
# ...      ...            ...                                     ...      ...
# 8687  615257      SS/GIJTA1      https://doi.org/10.17026/SS/GIJTA1      doi
# 8688  615280      SS/IHYCRX      https://doi.org/10.17026/SS/IHYCRX      doi
# 8689  615286      SS/ZY6QIP      https://doi.org/10.17026/SS/ZY6QIP      doi
# 8690  615288      SS/TM4SW5      https://doi.org/10.17026/SS/TM4SW5      doi
# 8691  615381      SS/APJCF3      https://doi.org/10.17026/SS/APJCF3      doi
#
#      authority                                         publisher  \
# 0     10.17026  DANS Data Station Social Sciences and Humanities
# 1     10.17026  DANS Data Station Social Sciences and Humanities
# 2     10.17026  DANS Data Station Social Sciences and Humanities
# 3     10.17026  DANS Data Station Social Sciences and Humanities
# 4     10.17026  DANS Data Station Social Sciences and Humanities
# ...        ...                                               ...
# 8687  10.17026  DANS Data Station Social Sciences and Humanities
# 8688  10.17026  DANS Data Station Social Sciences and Humanities
# 8689  10.17026  DANS Data Station Social Sciences and Humanities
# 8690  10.17026  DANS Data Station Social Sciences and Humanities
# 8691  10.17026  DANS Data Station Social Sciences and Humanities
#
#      publicationDate              storageIdentifier     type
# 0         1990-01-01  surf://10.17026/dans-zhr-eswk  dataset
# 1         1995-01-01  surf://10.17026/dans-xeh-f6xm  dataset
# 2         1999-01-01  surf://10.17026/dans-zct-en83  dataset
# 3         2004-01-01  surf://10.17026/dans-xjk-kqxa  dataset
# 4         1993-01-01  surf://10.17026/dans-xpa-uek9  dataset
# ...              ...                            ...      ...
# 8687      2025-05-28      surf://10.17026/SS/GIJTA1  dataset
# 8688      2025-05-13      surf://10.17026/SS/IHYCRX  dataset
# 8689      2025-05-12      surf://10.17026/SS/ZY6QIP  dataset
# 8690      2025-05-09      surf://10.17026/SS/TM4SW5  dataset
# 8691      2025-05-16      surf://10.17026/SS/APJCF3  dataset
#
# [8692 rows x 9 columns]

# %%
samples_dans = df_dans.sample(200)

# %% [markdown]
# ## ARCHE

# %% [markdown]
# ARCHE does not use Dataverse, but provides instead an API that returns RDF. We can use `rdflib` to parse this and extract all top-level datasets (there's only around 50 of them):

# %%
try:
    arche = pd.read_csv("arche.csv")

except FileNotFoundError:
    res = r.get("https://arche.acdh.oeaw.ac.at/api/search", params={
        "property[]": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
        "value[]": "https://vocabs.acdh.oeaw.ac.at/schema#TopCollection",
        "format": "application/n-triples",
        "readMode": "resource",
        "resourceProperties[]": "https://vocabs.acdh.oeaw.ac.at/schema#hasPid"
    })

    g = rdflib.Graph()
    g.parse(data=res.text, format='nt')

    pids = []

    for i in g:
        if str(i[1]) != "https://vocabs.acdh.oeaw.ac.at/schema#hasPid":
            continue
        pids.append(i[2])

    arche = pd.DataFrame({"persistentUrl": pids})
    arche.to_csv("arche.csv", index=False)

arche
# Out:
#                                        persistentUrl
# 0   https://hdl.handle.net/21.11115/0000-000E-558C-5
# 1   https://hdl.handle.net/21.11115/0000-000D-CA69-A
# 2   https://hdl.handle.net/21.11115/0000-000C-2093-9
# 3   https://hdl.handle.net/21.11115/0000-000F-8289-3
# 4   https://hdl.handle.net/21.11115/0000-000E-8C49-3
# 5   https://hdl.handle.net/21.11115/0000-0012-20EF-B
# 6   https://hdl.handle.net/21.11115/0000-0014-44CA-A
# 7   https://hdl.handle.net/21.11115/0000-0012-210C-A
# 8   https://hdl.handle.net/21.11115/0000-000C-35DB-2
# 9   https://hdl.handle.net/21.11115/0000-000B-DCC4-0
# 10  https://hdl.handle.net/21.11115/0000-000E-BCE0-1
# 11  https://hdl.handle.net/21.11115/0000-0016-7B39-F
# 12  https://hdl.handle.net/21.11115/0000-0012-B062-6
# 13  https://hdl.handle.net/21.11115/0000-000F-7406-8
# 14  https://hdl.handle.net/21.11115/0000-0011-BF16-E
# 15  https://hdl.handle.net/21.11115/0000-000D-D6FB-7
# 16  https://hdl.handle.net/21.11115/0000-000E-682A-F
# 17  https://hdl.handle.net/21.11115/0000-000F-FF98-7
# 18  https://hdl.handle.net/21.11115/0000-0016-83C7-3
# 19  https://hdl.handle.net/21.11115/0000-000E-8B71-6
# 20  https://hdl.handle.net/21.11115/0000-000E-7538-0
# 21  https://hdl.handle.net/21.11115/0000-0012-210E-8
# 22  https://hdl.handle.net/21.11115/0000-000C-2995-E
# 23  https://hdl.handle.net/21.11115/0000-000C-D928-3
# 24  https://hdl.handle.net/21.11115/0000-000D-FAB2-0
# 25  https://hdl.handle.net/21.11115/0000-000C-E89D-E
# 26  https://hdl.handle.net/21.11115/0000-000F-746A-8
# 27  https://hdl.handle.net/21.11115/0000-000C-4F1C-E
# 28  https://hdl.handle.net/21.11115/0000-000E-5198-B
# 29  https://hdl.handle.net/21.11115/0000-000E-C8A6-5
# 30  https://hdl.handle.net/21.11115/0000-000C-29A6-B
# 31  https://hdl.handle.net/21.11115/0000-0012-2113-1
# 32  https://hdl.handle.net/21.11115/0000-000F-3201-7
# 33  https://hdl.handle.net/21.11115/0000-0016-75BE-F
# 34  https://hdl.handle.net/21.11115/0000-0014-4404-9
# 35  https://hdl.handle.net/21.11115/0000-0012-F92B-4
# 36  https://hdl.handle.net/21.11115/0000-000C-D89B-2
# 37  https://hdl.handle.net/21.11115/0000-000C-E12A-7
# 38  https://hdl.handle.net/21.11115/0000-000B-C63A-5
# 39  https://hdl.handle.net/21.11115/0000-000F-9C36-5
# 40  https://hdl.handle.net/21.11115/0000-0013-BE8D-7
# 41  https://hdl.handle.net/21.11115/0000-000E-0FF1-2
# 42  https://hdl.handle.net/21.11115/0000-000D-FEAB-5
# 43  https://hdl.handle.net/21.11115/0000-0011-BF1F-5
# 44  https://hdl.handle.net/21.11115/0000-000C-29F3-4
# 45  https://hdl.handle.net/21.11115/0000-0012-F932-B
# 46  https://hdl.handle.net/21.11115/0000-000D-3979-C
# 47  https://hdl.handle.net/21.11115/0000-000D-D708-8
# 48  https://hdl.handle.net/21.11115/0000-000C-D99B-1
# 49  https://hdl.handle.net/21.11115/0000-000E-CE31-3

# %% [markdown]
# We build a final sample list out of the 200 chosen at random from DANS and the 50 from ARCHE:

# %%
try:
    samples = pd.read_csv("samples.csv").squeeze("columns")

except FileNotFoundError:
    samples = pd.concat([arche["persistentUrl"], samples_dans["persistentUrl"]], ignore_index=True)
    samples.to_csv("samples.csv", index=False)
samples
# Out:
# 0      https://hdl.handle.net/21.11115/0000-000E-558C-5
# 1      https://hdl.handle.net/21.11115/0000-000D-CA69-A
# 2      https://hdl.handle.net/21.11115/0000-000C-2093-9
# 3      https://hdl.handle.net/21.11115/0000-000F-8289-3
# 4      https://hdl.handle.net/21.11115/0000-000E-8C49-3
#                              ...
# 245              https://doi.org/10.17026/dans-2a2-77kp
# 246              https://doi.org/10.17026/dans-2ze-9e6y
# 247              https://doi.org/10.17026/dans-x58-jgbs
# 248              https://doi.org/10.17026/dans-zmd-zuj9
# 249              https://doi.org/10.17026/dans-xpe-2ksa
# Name: persistentUrl, Length: 250, dtype: object

# %% [markdown]
# ## FAIR Checker

# %% [markdown]
# FAIR Checker hosts an instance of its API online. We use this to get results for the 250 datasets:

# %%
def fair_checker_query(pid: str):
    res = r.get("https://fair-checker.france-bioinformatique.fr/api/check/legacy/metrics_all", params={"url": pid})

    if not res.ok:
        print(pid)
        print(res)
        return

    return {metric["metric"]: int(metric["score"]) for metric in res.json()}

# %%
def fair_checker(pids: pd.Series) -> pd.DataFrame:
    results = pids.progress_apply(fair_checker_query).apply(pd.Series)
    results.index = pids
    return results

# %%
try:
    results_fair_checker = pd.read_csv("fair_checker.csv", index_col="persistentUrl")
except FileNotFoundError:
    results_fair_checker = fair_checker(samples)
    results_fair_checker.to_csv("fair_checker.csv", index=True)

results_fair_checker
# Out:
#                                                   F1A  F1B  F2A  F2B  A1.1  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5  1.0  0.0  0.5  0.5   1.0
# https://hdl.handle.net/21.11115/0000-000D-CA69-A  1.0  0.0  0.5  0.5   1.0
# https://hdl.handle.net/21.11115/0000-000C-2093-9  1.0  0.0  0.5  0.5   1.0
# https://hdl.handle.net/21.11115/0000-000F-8289-3  1.0  0.0  0.5  0.5   1.0
# https://hdl.handle.net/21.11115/0000-000E-8C49-3  1.0  0.0  0.5  0.5   1.0
# ...                                               ...  ...  ...  ...   ...
# https://doi.org/10.17026/dans-2a2-77kp            1.0  1.0  0.5  0.5   1.0
# https://doi.org/10.17026/dans-2ze-9e6y            1.0  1.0  0.5  0.5   1.0
# https://doi.org/10.17026/dans-x58-jgbs            1.0  1.0  0.5  0.5   1.0
# https://doi.org/10.17026/dans-zmd-zuj9            1.0  1.0  0.5  0.5   1.0
# https://doi.org/10.17026/dans-xpe-2ksa            1.0  1.0  0.5  0.5   1.0
#
#                                                   A1.2   I1   I2   I3  R1.1  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5   0.0  0.5  0.5  1.0   0.0
# https://hdl.handle.net/21.11115/0000-000D-CA69-A   0.0  0.5  0.5  1.0   0.0
# https://hdl.handle.net/21.11115/0000-000C-2093-9   0.0  0.5  0.5  1.0   0.0
# https://hdl.handle.net/21.11115/0000-000F-8289-3   0.0  0.5  0.5  1.0   0.0
# https://hdl.handle.net/21.11115/0000-000E-8C49-3   0.0  0.5  0.5  1.0   0.0
# ...                                                ...  ...  ...  ...   ...
# https://doi.org/10.17026/dans-2a2-77kp             1.0  0.5  0.5  0.0   1.0
# https://doi.org/10.17026/dans-2ze-9e6y             1.0  0.5  0.5  0.0   1.0
# https://doi.org/10.17026/dans-x58-jgbs             1.0  0.5  0.5  1.0   1.0
# https://doi.org/10.17026/dans-zmd-zuj9             1.0  0.5  0.5  0.0   1.0
# https://doi.org/10.17026/dans-xpe-2ksa             1.0  0.5  0.5  0.0   1.0
#
#                                                   R1.2  R1.3
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5   0.0   0.5
# https://hdl.handle.net/21.11115/0000-000D-CA69-A   0.0   0.5
# https://hdl.handle.net/21.11115/0000-000C-2093-9   0.0   0.5
# https://hdl.handle.net/21.11115/0000-000F-8289-3   0.0   0.5
# https://hdl.handle.net/21.11115/0000-000E-8C49-3   0.0   0.5
# ...                                                ...   ...
# https://doi.org/10.17026/dans-2a2-77kp             1.0   0.5
# https://doi.org/10.17026/dans-2ze-9e6y             1.0   0.5
# https://doi.org/10.17026/dans-x58-jgbs             1.0   0.5
# https://doi.org/10.17026/dans-zmd-zuj9             1.0   0.5
# https://doi.org/10.17026/dans-xpe-2ksa             1.0   0.5
#
# [250 rows x 12 columns]

# %%
final_fair_checker = pd.concat([
    results_fair_checker.loc[:, results_fair_checker.columns.str.startswith("F")].mean(axis=1).to_frame("Findability"),
    results_fair_checker.loc[:, results_fair_checker.columns.str.startswith("A")].mean(axis=1).to_frame("Accessibility"),
    results_fair_checker.loc[:, results_fair_checker.columns.str.startswith("I")].mean(axis=1).to_frame("Interoperability"),
    results_fair_checker.loc[:, results_fair_checker.columns.str.startswith("R")].mean(axis=1).to_frame("Reusability"),
    results_fair_checker.mean(axis=1).to_frame("Overall"),
], axis=1)

final_fair_checker
# Out:
#                                                   Findability  Accessibility  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5         0.50            0.5
# https://hdl.handle.net/21.11115/0000-000D-CA69-A         0.50            0.5
# https://hdl.handle.net/21.11115/0000-000C-2093-9         0.50            0.5
# https://hdl.handle.net/21.11115/0000-000F-8289-3         0.50            0.5
# https://hdl.handle.net/21.11115/0000-000E-8C49-3         0.50            0.5
# ...                                                       ...            ...
# https://doi.org/10.17026/dans-2a2-77kp                   0.75            1.0
# https://doi.org/10.17026/dans-2ze-9e6y                   0.75            1.0
# https://doi.org/10.17026/dans-x58-jgbs                   0.75            1.0
# https://doi.org/10.17026/dans-zmd-zuj9                   0.75            1.0
# https://doi.org/10.17026/dans-xpe-2ksa                   0.75            1.0
#
#                                                   Interoperability  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5          0.666667
# https://hdl.handle.net/21.11115/0000-000D-CA69-A          0.666667
# https://hdl.handle.net/21.11115/0000-000C-2093-9          0.666667
# https://hdl.handle.net/21.11115/0000-000F-8289-3          0.666667
# https://hdl.handle.net/21.11115/0000-000E-8C49-3          0.666667
# ...                                                            ...
# https://doi.org/10.17026/dans-2a2-77kp                    0.333333
# https://doi.org/10.17026/dans-2ze-9e6y                    0.333333
# https://doi.org/10.17026/dans-x58-jgbs                    0.666667
# https://doi.org/10.17026/dans-zmd-zuj9                    0.333333
# https://doi.org/10.17026/dans-xpe-2ksa                    0.333333
#
#                                                   Reusability   Overall
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5     0.166667  0.458333
# https://hdl.handle.net/21.11115/0000-000D-CA69-A     0.166667  0.458333
# https://hdl.handle.net/21.11115/0000-000C-2093-9     0.166667  0.458333
# https://hdl.handle.net/21.11115/0000-000F-8289-3     0.166667  0.458333
# https://hdl.handle.net/21.11115/0000-000E-8C49-3     0.166667  0.458333
# ...                                                       ...       ...
# https://doi.org/10.17026/dans-2a2-77kp               0.833333  0.708333
# https://doi.org/10.17026/dans-2ze-9e6y               0.833333  0.708333
# https://doi.org/10.17026/dans-x58-jgbs               0.833333  0.791667
# https://doi.org/10.17026/dans-zmd-zuj9               0.833333  0.708333
# https://doi.org/10.17026/dans-xpe-2ksa               0.833333  0.708333
#
# [250 rows x 5 columns]

# %% [markdown]
# ## F-UJI

# %% [markdown]
# F-UJI does not provide a hosted API instance. We thus have to host it locally, and we can do that with the provided `docker-compose.yml` file by running `docker compose up` in the project's directory. We can then use it to process the samples:

# %%
FUJI_URL = "http://localhost:1071/fuji/api/v1/evaluate"

# %%
def fuji_query(pid: str):
    headers = {
        "accept": "application/json",
        "Authorization": "Basic bWFydmVsOndvbmRlcndvbWFu",
        "Content-Type": "application/json",
    }

    req = {"object_identifier": pid, "use_datacite": True}
    res = r.post(FUJI_URL, json=req, headers=headers).json()

    return {metric: score / res["summary"]["score_total"][metric] for metric, score in res["summary"]["score_earned"].items()}

# %%
def fuji(pids: pd.Series) -> pd.DataFrame:
    results = pids.progress_apply(fuji_query).apply(pd.Series)
    results.index = pids
    return results

# %%
try:
    results_fuji = pd.read_csv("fuji.csv", index_col="persistentUrl")

except FileNotFoundError:
    results_fuji: pd.DataFrame = fuji(samples)

results_fuji
# Out:
#                                                          A         F     I  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5  0.333333  0.357143  0.25
# https://hdl.handle.net/21.11115/0000-000D-CA69-A  0.333333  0.357143  0.25
# https://hdl.handle.net/21.11115/0000-000C-2093-9  0.333333  0.357143  0.25
# https://hdl.handle.net/21.11115/0000-000F-8289-3  0.333333  0.357143  0.25
# https://hdl.handle.net/21.11115/0000-000E-8C49-3  0.333333  0.357143  0.25
# ...                                                    ...       ...   ...
# https://doi.org/10.17026/dans-2a2-77kp            0.666667  1.000000  0.75
# https://doi.org/10.17026/dans-2ze-9e6y            0.666667  1.000000  0.75
# https://doi.org/10.17026/dans-x58-jgbs            0.666667  1.000000  0.75
# https://doi.org/10.17026/dans-zmd-zuj9            1.000000  1.000000  0.75
# https://doi.org/10.17026/dans-xpe-2ksa            1.000000  1.000000  0.75
#
#                                                     R        A1   F1    F2  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5  0.0  0.333333  1.0  0.25
# https://hdl.handle.net/21.11115/0000-000D-CA69-A  0.0  0.333333  1.0  0.25
# https://hdl.handle.net/21.11115/0000-000C-2093-9  0.0  0.333333  1.0  0.25
# https://hdl.handle.net/21.11115/0000-000F-8289-3  0.0  0.333333  1.0  0.25
# https://hdl.handle.net/21.11115/0000-000E-8C49-3  0.0  0.333333  1.0  0.25
# ...                                               ...       ...  ...   ...
# https://doi.org/10.17026/dans-2a2-77kp            0.7  0.666667  1.0  1.00
# https://doi.org/10.17026/dans-2ze-9e6y            0.7  0.666667  1.0  1.00
# https://doi.org/10.17026/dans-x58-jgbs            0.8  0.666667  1.0  1.00
# https://doi.org/10.17026/dans-zmd-zuj9            0.7  1.000000  1.0  1.00
# https://doi.org/10.17026/dans-xpe-2ksa            0.7  1.000000  1.0  1.00
#
#                                                    F3   F4   I1   I2   I3  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5  0.0  0.0  0.5  0.0  0.0
# https://hdl.handle.net/21.11115/0000-000D-CA69-A  0.0  0.0  0.5  0.0  0.0
# https://hdl.handle.net/21.11115/0000-000C-2093-9  0.0  0.0  0.5  0.0  0.0
# https://hdl.handle.net/21.11115/0000-000F-8289-3  0.0  0.0  0.5  0.0  0.0
# https://hdl.handle.net/21.11115/0000-000E-8C49-3  0.0  0.0  0.5  0.0  0.0
# ...                                               ...  ...  ...  ...  ...
# https://doi.org/10.17026/dans-2a2-77kp            1.0  1.0  1.0  0.0  1.0
# https://doi.org/10.17026/dans-2ze-9e6y            1.0  1.0  1.0  0.0  1.0
# https://doi.org/10.17026/dans-x58-jgbs            1.0  1.0  1.0  0.0  1.0
# https://doi.org/10.17026/dans-zmd-zuj9            1.0  1.0  1.0  0.0  1.0
# https://doi.org/10.17026/dans-xpe-2ksa            1.0  1.0  1.0  0.0  1.0
#
#                                                     R1  R1.1  R1.2  R1.3  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5  0.00   0.0   0.0   0.0
# https://hdl.handle.net/21.11115/0000-000D-CA69-A  0.00   0.0   0.0   0.0
# https://hdl.handle.net/21.11115/0000-000C-2093-9  0.00   0.0   0.0   0.0
# https://hdl.handle.net/21.11115/0000-000F-8289-3  0.00   0.0   0.0   0.0
# https://hdl.handle.net/21.11115/0000-000E-8C49-3  0.00   0.0   0.0   0.0
# ...                                                ...   ...   ...   ...
# https://doi.org/10.17026/dans-2a2-77kp            0.75   0.5   0.5   1.0
# https://doi.org/10.17026/dans-2ze-9e6y            0.75   0.5   0.5   1.0
# https://doi.org/10.17026/dans-x58-jgbs            0.75   1.0   0.5   1.0
# https://doi.org/10.17026/dans-zmd-zuj9            0.75   0.5   0.5   1.0
# https://doi.org/10.17026/dans-xpe-2ksa            0.75   0.5   0.5   1.0
#
#                                                       FAIR
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5  0.187500
# https://hdl.handle.net/21.11115/0000-000D-CA69-A  0.187500
# https://hdl.handle.net/21.11115/0000-000C-2093-9  0.187500
# https://hdl.handle.net/21.11115/0000-000F-8289-3  0.187500
# https://hdl.handle.net/21.11115/0000-000E-8C49-3  0.187500
# ...                                                    ...
# https://doi.org/10.17026/dans-2a2-77kp            0.791667
# https://doi.org/10.17026/dans-2ze-9e6y            0.791667
# https://doi.org/10.17026/dans-x58-jgbs            0.833333
# https://doi.org/10.17026/dans-zmd-zuj9            0.833333
# https://doi.org/10.17026/dans-xpe-2ksa            0.833333
#
# [250 rows x 17 columns]

# %%
final_fuji = results_fuji[["F", "A", "I", "R", "FAIR"]].rename(columns={
    "F": "Findability",
    "A": "Accessibility",
    "I": "Interoperability",
    "R": "Reusability",
    "FAIR": "Overall",
})

final_fuji.index = samples
final_fuji
# Out:
#                                                   Findability  Accessibility  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5     0.357143       0.333333
# https://hdl.handle.net/21.11115/0000-000D-CA69-A     0.357143       0.333333
# https://hdl.handle.net/21.11115/0000-000C-2093-9     0.357143       0.333333
# https://hdl.handle.net/21.11115/0000-000F-8289-3     0.357143       0.333333
# https://hdl.handle.net/21.11115/0000-000E-8C49-3     0.357143       0.333333
# ...                                                       ...            ...
# https://doi.org/10.17026/dans-2a2-77kp               1.000000       0.666667
# https://doi.org/10.17026/dans-2ze-9e6y               1.000000       0.666667
# https://doi.org/10.17026/dans-x58-jgbs               1.000000       0.666667
# https://doi.org/10.17026/dans-zmd-zuj9               1.000000       1.000000
# https://doi.org/10.17026/dans-xpe-2ksa               1.000000       1.000000
#
#                                                   Interoperability  \
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5              0.25
# https://hdl.handle.net/21.11115/0000-000D-CA69-A              0.25
# https://hdl.handle.net/21.11115/0000-000C-2093-9              0.25
# https://hdl.handle.net/21.11115/0000-000F-8289-3              0.25
# https://hdl.handle.net/21.11115/0000-000E-8C49-3              0.25
# ...                                                            ...
# https://doi.org/10.17026/dans-2a2-77kp                        0.75
# https://doi.org/10.17026/dans-2ze-9e6y                        0.75
# https://doi.org/10.17026/dans-x58-jgbs                        0.75
# https://doi.org/10.17026/dans-zmd-zuj9                        0.75
# https://doi.org/10.17026/dans-xpe-2ksa                        0.75
#
#                                                   Reusability   Overall
# persistentUrl
# https://hdl.handle.net/21.11115/0000-000E-558C-5          0.0  0.187500
# https://hdl.handle.net/21.11115/0000-000D-CA69-A          0.0  0.187500
# https://hdl.handle.net/21.11115/0000-000C-2093-9          0.0  0.187500
# https://hdl.handle.net/21.11115/0000-000F-8289-3          0.0  0.187500
# https://hdl.handle.net/21.11115/0000-000E-8C49-3          0.0  0.187500
# ...                                                       ...       ...
# https://doi.org/10.17026/dans-2a2-77kp                    0.7  0.791667
# https://doi.org/10.17026/dans-2ze-9e6y                    0.7  0.791667
# https://doi.org/10.17026/dans-x58-jgbs                    0.8  0.833333
# https://doi.org/10.17026/dans-zmd-zuj9                    0.7  0.833333
# https://doi.org/10.17026/dans-xpe-2ksa                    0.7  0.833333
#
# [250 rows x 5 columns]

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Cross-tabulation

# %%
def data_crosstab(df: pd.DataFrame) -> pd.DataFrame:
    melted = df.melt(var_name="metric", value_name="value")

    bins = [0, 0.25, 0.5, 0.75, 1.0]
    bin_labels = ['0%-25%', '25%-50%', '50%-75%', '75%-100%']

    melted['bin'] = pd.cut(melted['value'], bins=bins, labels=bin_labels, include_lowest=True)

    return pd.crosstab(melted["metric"], melted["bin"]).loc[df.columns]

# %%
crosstab_fair_checker = data_crosstab(final_fair_checker)
crosstab_fair_checker
# Out:
# bin               0%-25%  25%-50%  50%-75%  75%-100%
# Findability            6       56      188         0
# Accessibility          0       62        0       188
# Interoperability       6      150       94         0
# Reusability           62        0        0       188
# Overall                6       56      144        44

# %%
crosstab_fuji = data_crosstab(final_fuji)
crosstab_fuji
# Out:
# bin               0%-25%  25%-50%  50%-75%  75%-100%
# Findability            0       50        6       194
# Accessibility          0       62       77       111
# Interoperability      49       16      185         0
# Reusability           50       15      150        35
# Overall               50       12        3       185

# %% [markdown]
# ## Correlation of results between the two tools

# %%
def data_correlate(df1: pd.DataFrame, df2: pd.DataFrame) -> pd.DataFrame:

    return pd.DataFrame([df1[col].corr(df2[col]) for col in df1.columns], index=df1.columns)

# %%
correlation = data_correlate(final_fair_checker, final_fuji)
correlation
# Out:
#                          0
# Findability       0.883569
# Accessibility     0.849621
# Interoperability -0.341329
# Reusability       0.950187
# Overall           0.877238

# %% [markdown]
# # Export to LaTeX

# %%
crosstab_fair_checker.to_latex("crosstab_fair_checker.tex")
crosstab_fuji.to_latex("crosstab_fuji.tex")
correlation.to_latex("correlation.tex")
