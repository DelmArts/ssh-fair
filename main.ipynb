# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests as r

# %% [markdown]
# ## Dumping DANS

# %% [markdown]
# First, we use the pyDataverse library to connect to the DANS repository (it's a dataverse repository)
#
# https://pydataverse.readthedocs.io/en/latest/user/basic-usage.html#connect-to-native-api

# %%
from pyDataverse.api import NativeApi
api = NativeApi("https://ssh.datastations.nl/")

api.get_info_version().json()
# Out:
# {'status': 'OK',
#  'data': {'version': '6.3', 'build': 'DANS-DataStation-PATCH-9'}}

# %% [markdown]
# We dump the entire repository by getting the contents of the special dataverse ":root". Warning: this takes like 15 mins.

# %%
tree = api.get_dataverse_contents(":root")

tree.json()
# Out:
# {'status': 'OK',
#  'data': [{'id': 1920,
#    'identifier': 'dans-zhr-eswk',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zhr-eswk',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1990-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-zhr-eswk',
#    'type': 'dataset'},
#   {'id': 1921,
#    'identifier': 'dans-xeh-f6xm',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xeh-f6xm',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1995-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-xeh-f6xm',
#    'type': 'dataset'},
#   {'id': 1924,
#    'identifier': 'dans-zct-en83',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zct-en83',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1999-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-zct-en83',
#    'type': 'dataset'},
#   {'id': 1949,
#    'identifier': 'dans-xjk-kqxa',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xjk-kqxa',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2004-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-xjk-kqxa',
#    'type': 'dataset'},
#   {'id': 2082,
#    'identifier': 'dans-xpa-uek9',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xpa-uek9',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1993-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-xpa-uek9',
#    'type': 'dataset'},
#   {'id': 3760,
#    'identifier': 'dans-zhv-f5cf',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zhv-f5cf',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-19',
#    'storageIdentifier': 'surf://10.17026/dans-zhv-f5cf',
#    'type': 'dataset'},
#   {'id': 3761,
#    'identifier': 'dans-28e-auee',
#    'persistentUrl': 'https://doi.org/10.17026/dans-28e-auee',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-28e-auee',
#    'type': 'dataset'},
#   {'id': 3764,
#    'identifier': 'dans-xs7-zscf',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xs7-zscf',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xs7-zscf',
#    'type': 'dataset'},
#   {'id': 3765,
#    'identifier': 'dans-z8q-z6px',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z8q-z6px',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-z8q-z6px',
#    'type': 'dataset'},
#   {'id': 3768,
#    'identifier': 'dans-xuy-5c7h',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xuy-5c7h',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xuy-5c7h',
#    'type': 'dataset'},
#   {'id': 3769,
#    'identifier': 'dans-2z3-8kh5',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2z3-8kh5',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-2z3-8kh5',
#    'type': 'dataset'},
#   {'id': 3772,
#    'identifier': 'dans-x9p-mqbs',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x9p-mqbs',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-x9p-mqbs',
#    'type': 'dataset'},
#   {'id': 3773,
#    'identifier': 'dans-zcm-447g',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zcm-447g',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-zcm-447g',
#    'type': 'dataset'},
#   {'id': 3776,
#    'identifier': 'dans-25a-a85a',
#    'persistentUrl': 'https://doi.org/10.17026/dans-25a-a85a',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-25a-a85a',
#    'type': 'dataset'},
#   {'id': 3777,
#    'identifier': 'dans-2a3-bd7h',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2a3-bd7h',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-2a3-bd7h',
#    'type': 'dataset'},
#   {'id': 3780,
#    'identifier': 'dans-xqh-vv45',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xqh-vv45',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xqh-vv45',
#    'type': 'dataset'},
#   {'id': 3781,
#    'identifier': 'dans-zv6-jmm6',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zv6-jmm6',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-zv6-jmm6',
#    'type': 'dataset'},
#   {'id': 3784,
#    'identifier': 'dans-29u-jhha',
#    'persistentUrl': 'https://doi.org/10.17026/dans-29u-jhha',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-29u-jhha',
#    'type': 'dataset'},
#   {'id': 3785,
#    'identifier': 'dans-x7e-5anu',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x7e-5anu',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-x7e-5anu',
#    'type': 'dataset'},
#   {'id': 3788,
#    'identifier': 'dans-z7q-4k6u',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z7q-4k6u',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-z7q-4k6u',
#    'type': 'dataset'},
#   {'id': 3789,
#    'identifier': 'dans-xte-8m9r',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xte-8m9r',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xte-8m9r',
#    'type': 'dataset'},
#   {'id': 3792,
#    'identifier': 'dans-xpz-a2sb',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xpz-a2sb',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xpz-a2sb',
#    'type': 'dataset'},
#   {'id': 3793,
#    'identifier': 'dans-z3q-p6x5',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z3q-p6x5',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-z3q-p6x5',
#    'type': 'dataset'},
#   {'id': 3796,
#    'identifier': 'dans-xsv-7nvy',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xsv-7nvy',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xsv-7nvy',
#    'type': 'dataset'},
#   {'id': 3797,
#    'identifier': 'dans-xex-ug8y',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xex-ug8y',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xex-ug8y',
#    'type': 'dataset'},
#   {'id': 3800,
#    'identifier': 'dans-xfz-emjs',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xfz-emjs',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xfz-emjs',
#    'type': 'dataset'},
#   {'id': 3801,
#    'identifier': 'dans-xbk-uxhg',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xbk-uxhg',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xbk-uxhg',
#    'type': 'dataset'},
#   {'id': 3804,
#    'identifier': 'dans-zaa-97be',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zaa-97be',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-zaa-97be',
#    'type': 'dataset'},
#   {'id': 3805,
#    'identifier': 'dans-z48-zm88',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z48-zm88',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-z48-zm88',
#    'type': 'dataset'},
#   {'id': 3808,
#    'identifier': 'dans-x54-uf8e',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x54-uf8e',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-x54-uf8e',
#    'type': 'dataset'},
#   {'id': 3809,
#    'identifier': 'dans-xas-4ucf',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xas-4ucf',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-09-12',
#    'storageIdentifier': 'surf://10.17026/dans-xas-4ucf',
#    'type': 'dataset'},
#   {'id': 3812,
#    'identifier': 'dans-2xw-rxug',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2xw-rxug',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-08-26',
#    'storageIdentifier': 'surf://10.17026/dans-2xw-rxug',
#    'type': 'dataset'},
#   {'id': 3816,
#    'identifier': 'dans-xa9-52hc',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xa9-52hc',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-08-26',
#    'storageIdentifier': 'surf://10.17026/dans-xa9-52hc',
#    'type': 'dataset'},
#   {'id': 3817,
#    'identifier': 'dans-zzy-nnry',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zzy-nnry',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-08-26',
#    'storageIdentifier': 'surf://10.17026/dans-zzy-nnry',
#    'type': 'dataset'},
#   {'id': 3820,
#    'identifier': 'dans-z6x-xkmh',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z6x-xkmh',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-08-26',
#    'storageIdentifier': 'surf://10.17026/dans-z6x-xkmh',
#    'type': 'dataset'},
#   {'id': 3821,
#    'identifier': 'dans-xkv-hssc',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xkv-hssc',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-08-26',
#    'storageIdentifier': 'surf://10.17026/dans-xkv-hssc',
#    'type': 'dataset'},
#   {'id': 3824,
#    'identifier': 'dans-zr5-r23g',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zr5-r23g',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-08-26',
#    'storageIdentifier': 'surf://10.17026/dans-zr5-r23g',
#    'type': 'dataset'},
#   {'id': 3825,
#    'identifier': 'dans-294-zgr3',
#    'persistentUrl': 'https://doi.org/10.17026/dans-294-zgr3',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2013-08-26',
#    'storageIdentifier': 'surf://10.17026/dans-294-zgr3',
#    'type': 'dataset'},
#   {'id': 4113,
#    'identifier': 'dans-z2c-vy47',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z2c-vy47',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2016-08-01',
#    'storageIdentifier': 'surf://10.17026/dans-z2c-vy47',
#    'type': 'dataset'},
#   {'id': 4120,
#    'identifier': 'dans-2zw-wan9',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2zw-wan9',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-2zw-wan9',
#    'type': 'dataset'},
#   {'id': 4121,
#    'identifier': 'dans-zrw-xuuv',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zrw-xuuv',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-zrw-xuuv',
#    'type': 'dataset'},
#   {'id': 4135,
#    'identifier': 'dans-2ag-r7aa',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2ag-r7aa',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-2ag-r7aa',
#    'type': 'dataset'},
#   {'id': 4139,
#    'identifier': 'dans-zn9-p6nw',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zn9-p6nw',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-zn9-p6nw',
#    'type': 'dataset'},
#   {'id': 4149,
#    'identifier': 'dans-xmy-rz5k',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xmy-rz5k',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-xmy-rz5k',
#    'type': 'dataset'},
#   {'id': 4154,
#    'identifier': 'dans-24m-uj9r',
#    'persistentUrl': 'https://doi.org/10.17026/dans-24m-uj9r',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2014-12-22',
#    'storageIdentifier': 'surf://10.17026/dans-24m-uj9r',
#    'type': 'dataset'},
#   {'id': 4165,
#    'identifier': 'dans-z6g-bm2u',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z6g-bm2u',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-z6g-bm2u',
#    'type': 'dataset'},
#   {'id': 4172,
#    'identifier': 'dans-zgs-6dra',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zgs-6dra',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-zgs-6dra',
#    'type': 'dataset'},
#   {'id': 4182,
#    'identifier': 'dans-x9j-5t2u',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x9j-5t2u',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-x9j-5t2u',
#    'type': 'dataset'},
#   {'id': 4198,
#    'identifier': 'dans-xpz-85w5',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xpz-85w5',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-xpz-85w5',
#    'type': 'dataset'},
#   {'id': 4205,
#    'identifier': 'dans-zga-bj83',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zga-bj83',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-zga-bj83',
#    'type': 'dataset'},
#   {'id': 4206,
#    'identifier': 'dans-2xb-jrjt',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2xb-jrjt',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-2xb-jrjt',
#    'type': 'dataset'},
#   {'id': 4221,
#    'identifier': 'dans-xmu-8fd8',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xmu-8fd8',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-xmu-8fd8',
#    'type': 'dataset'},
#   {'id': 4229,
#    'identifier': 'dans-zhh-2kqs',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zhh-2kqs',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-zhh-2kqs',
#    'type': 'dataset'},
#   {'id': 4237,
#    'identifier': 'dans-2bq-7k4f',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2bq-7k4f',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-2bq-7k4f',
#    'type': 'dataset'},
#   {'id': 4242,
#    'identifier': 'dans-x3e-nm8n',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x3e-nm8n',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-x3e-nm8n',
#    'type': 'dataset'},
#   {'id': 4255,
#    'identifier': 'dans-xwg-bee8',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xwg-bee8',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2015-06-15',
#    'storageIdentifier': 'surf://10.17026/dans-xwg-bee8',
#    'type': 'dataset'},
#   {'id': 4256,
#    'identifier': 'dans-x7f-xfqq',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x7f-xfqq',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-30',
#    'storageIdentifier': 'surf://10.17026/dans-x7f-xfqq',
#    'type': 'dataset'},
#   {'id': 4268,
#    'identifier': 'dans-zs7-y3jk',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zs7-y3jk',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2015-07-28',
#    'storageIdentifier': 'surf://10.17026/dans-zs7-y3jk',
#    'type': 'dataset'},
#   {'id': 4276,
#    'identifier': 'dans-x92-ptzs',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x92-ptzs',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2015-02-23',
#    'storageIdentifier': 'surf://10.17026/dans-x92-ptzs',
#    'type': 'dataset'},
#   {'id': 4284,
#    'identifier': 'dans-xdu-8j3m',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xdu-8j3m',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2015-01-08',
#    'storageIdentifier': 'surf://10.17026/dans-xdu-8j3m',
#    'type': 'dataset'},
#   {'id': 4292,
#    'identifier': 'dans-xnm-uj4f',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xnm-uj4f',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2015-07-28',
#    'storageIdentifier': 'surf://10.17026/dans-xnm-uj4f',
#    'type': 'dataset'},
#   {'id': 4300,
#    'identifier': 'dans-xby-5dhs',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xby-5dhs',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-xby-5dhs',
#    'type': 'dataset'},
#   {'id': 4309,
#    'identifier': 'dans-zuu-ustu',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zuu-ustu',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-01-19',
#    'storageIdentifier': 'surf://10.17026/dans-zuu-ustu',
#    'type': 'dataset'},
#   {'id': 4335,
#    'identifier': 'dans-zub-cav2',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zub-cav2',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-05',
#    'storageIdentifier': 'surf://10.17026/dans-zub-cav2',
#    'type': 'dataset'},
#   {'id': 4336,
#    'identifier': 'dans-xpc-abaj',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xpc-abaj',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-07',
#    'storageIdentifier': 'surf://10.17026/dans-xpc-abaj',
#    'type': 'dataset'},
#   {'id': 4346,
#    'identifier': 'dans-26a-vcmz',
#    'persistentUrl': 'https://doi.org/10.17026/dans-26a-vcmz',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-26a-vcmz',
#    'type': 'dataset'},
#   {'id': 4355,
#    'identifier': 'dans-xnz-uczw',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xnz-uczw',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-xnz-uczw',
#    'type': 'dataset'},
#   {'id': 4358,
#    'identifier': 'dans-23b-sksj',
#    'persistentUrl': 'https://doi.org/10.17026/dans-23b-sksj',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-23b-sksj',
#    'type': 'dataset'},
#   {'id': 4361,
#    'identifier': 'dans-zru-apug',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zru-apug',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-zru-apug',
#    'type': 'dataset'},
#   {'id': 4364,
#    'identifier': 'dans-z7b-8g8x',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z7b-8g8x',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-z7b-8g8x',
#    'type': 'dataset'},
#   {'id': 4367,
#    'identifier': 'dans-x2j-xcfy',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x2j-xcfy',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-x2j-xcfy',
#    'type': 'dataset'},
#   {'id': 4370,
#    'identifier': 'dans-22x-gtu3',
#    'persistentUrl': 'https://doi.org/10.17026/dans-22x-gtu3',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-22x-gtu3',
#    'type': 'dataset'},
#   {'id': 4373,
#    'identifier': 'dans-xju-h3db',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xju-h3db',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-xju-h3db',
#    'type': 'dataset'},
#   {'id': 4376,
#    'identifier': 'dans-z85-nu8v',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z85-nu8v',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-z85-nu8v',
#    'type': 'dataset'},
#   {'id': 4379,
#    'identifier': 'dans-2z4-g4aw',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2z4-g4aw',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-2z4-g4aw',
#    'type': 'dataset'},
#   {'id': 4383,
#    'identifier': 'dans-zuq-r32t',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zuq-r32t',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-zuq-r32t',
#    'type': 'dataset'},
#   {'id': 4386,
#    'identifier': 'dans-xb8-bqfk',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xb8-bqfk',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2016-12-01',
#    'storageIdentifier': 'surf://10.17026/dans-xb8-bqfk',
#    'type': 'dataset'},
#   {'id': 4389,
#    'identifier': 'dans-z2s-62hm',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z2s-62hm',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1998-11-01',
#    'storageIdentifier': 'surf://10.17026/dans-z2s-62hm',
#    'type': 'dataset'},
#   {'id': 4406,
#    'identifier': 'dans-x5g-phsg',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x5g-phsg',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-13',
#    'storageIdentifier': 'surf://10.17026/dans-x5g-phsg',
#    'type': 'dataset'},
#   {'id': 4409,
#    'identifier': 'dans-xgz-qaft',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xgz-qaft',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-29',
#    'storageIdentifier': 'surf://10.17026/dans-xgz-qaft',
#    'type': 'dataset'},
#   {'id': 4428,
#    'identifier': 'dans-xxt-9d28',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xxt-9d28',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-07-27',
#    'storageIdentifier': 'surf://10.17026/dans-xxt-9d28',
#    'type': 'dataset'},
#   {'id': 4477,
#    'identifier': 'dans-xhh-e3au',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xhh-e3au',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-xhh-e3au',
#    'type': 'dataset'},
#   {'id': 4485,
#    'identifier': 'dans-x74-cez7',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x74-cez7',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-x74-cez7',
#    'type': 'dataset'},
#   {'id': 4530,
#    'identifier': 'dans-25k-tzar',
#    'persistentUrl': 'https://doi.org/10.17026/dans-25k-tzar',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-25k-tzar',
#    'type': 'dataset'},
#   {'id': 4558,
#    'identifier': 'dans-z6u-dmfb',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z6u-dmfb',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-z6u-dmfb',
#    'type': 'dataset'},
#   {'id': 4566,
#    'identifier': 'dans-2cv-mtdp',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2cv-mtdp',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-2cv-mtdp',
#    'type': 'dataset'},
#   {'id': 4574,
#    'identifier': 'dans-zty-ahz9',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zty-ahz9',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zty-ahz9',
#    'type': 'dataset'},
#   {'id': 4585,
#    'identifier': 'dans-2a3-eyk3',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2a3-eyk3',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-2a3-eyk3',
#    'type': 'dataset'},
#   {'id': 4593,
#    'identifier': 'dans-zpq-pfqc',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zpq-pfqc',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zpq-pfqc',
#    'type': 'dataset'},
#   {'id': 4601,
#    'identifier': 'dans-x9x-j7kx',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x9x-j7kx',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-x9x-j7kx',
#    'type': 'dataset'},
#   {'id': 4610,
#    'identifier': 'dans-2xa-4kzs',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2xa-4kzs',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-2xa-4kzs',
#    'type': 'dataset'},
#   {'id': 4617,
#    'identifier': 'dans-zuk-mg22',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zuk-mg22',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zuk-mg22',
#    'type': 'dataset'},
#   {'id': 4625,
#    'identifier': 'dans-zup-x9pb',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zup-x9pb',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zup-x9pb',
#    'type': 'dataset'},
#   {'id': 4633,
#    'identifier': 'dans-xeq-xgwc',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xeq-xgwc',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-xeq-xgwc',
#    'type': 'dataset'},
#   {'id': 4641,
#    'identifier': 'dans-zup-jm7c',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zup-jm7c',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zup-jm7c',
#    'type': 'dataset'},
#   {'id': 4649,
#    'identifier': 'dans-zw4-fsr8',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zw4-fsr8',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zw4-fsr8',
#    'type': 'dataset'},
#   {'id': 4657,
#    'identifier': 'dans-zpk-x6ef',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zpk-x6ef',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zpk-x6ef',
#    'type': 'dataset'},
#   {'id': 4663,
#    'identifier': 'dans-z28-3f33',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z28-3f33',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-z28-3f33',
#    'type': 'dataset'},
#   {'id': 4671,
#    'identifier': 'dans-z83-y72z',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z83-y72z',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-z83-y72z',
#    'type': 'dataset'},
#   {'id': 4679,
#    'identifier': 'dans-zmy-cvps',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zmy-cvps',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zmy-cvps',
#    'type': 'dataset'},
#   {'id': 4687,
#    'identifier': 'dans-xh2-839f',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xh2-839f',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-xh2-839f',
#    'type': 'dataset'},
#   {'id': 4696,
#    'identifier': 'dans-xuu-m45s',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xuu-m45s',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-xuu-m45s',
#    'type': 'dataset'},
#   {'id': 4705,
#    'identifier': 'dans-x2a-9zkp',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x2a-9zkp',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-x2a-9zkp',
#    'type': 'dataset'},
#   {'id': 4714,
#    'identifier': 'dans-xg7-8jnk',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xg7-8jnk',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-xg7-8jnk',
#    'type': 'dataset'},
#   {'id': 4723,
#    'identifier': 'dans-zcr-q7av',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zcr-q7av',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-zcr-q7av',
#    'type': 'dataset'},
#   {'id': 4727,
#    'identifier': 'dans-x7u-7waz',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x7u-7waz',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-x7u-7waz',
#    'type': 'dataset'},
#   {'id': 4741,
#    'identifier': 'dans-z93-hkd3',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z93-hkd3',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-09-25',
#    'storageIdentifier': 'surf://10.17026/dans-z93-hkd3',
#    'type': 'dataset'},
#   {'id': 4742,
#    'identifier': 'dans-xzz-zc7v',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xzz-zc7v',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-19',
#    'storageIdentifier': 'surf://10.17026/dans-xzz-zc7v',
#    'type': 'dataset'},
#   {'id': 4747,
#    'identifier': 'dans-xpw-5bmu',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xpw-5bmu',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-19',
#    'storageIdentifier': 'surf://10.17026/dans-xpw-5bmu',
#    'type': 'dataset'},
#   {'id': 4750,
#    'identifier': 'dans-zex-bn4w',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zex-bn4w',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-19',
#    'storageIdentifier': 'surf://10.17026/dans-zex-bn4w',
#    'type': 'dataset'},
#   {'id': 4753,
#    'identifier': 'dans-z3u-jnud',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z3u-jnud',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-19',
#    'storageIdentifier': 'surf://10.17026/dans-z3u-jnud',
#    'type': 'dataset'},
#   {'id': 4756,
#    'identifier': 'dans-x8b-syx8',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x8b-syx8',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-02-09',
#    'storageIdentifier': 'surf://10.17026/dans-x8b-syx8',
#    'type': 'dataset'},
#   {'id': 4762,
#    'identifier': 'dans-zfr-cnen',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zfr-cnen',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-01-19',
#    'storageIdentifier': 'surf://10.17026/dans-zfr-cnen',
#    'type': 'dataset'},
#   {'id': 4768,
#    'identifier': 'dans-z6q-qec9',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z6q-qec9',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-02-17',
#    'storageIdentifier': 'surf://10.17026/dans-z6q-qec9',
#    'type': 'dataset'},
#   {'id': 4779,
#    'identifier': 'dans-zt7-6aqw',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zt7-6aqw',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-09-26',
#    'storageIdentifier': 'surf://10.17026/dans-zt7-6aqw',
#    'type': 'dataset'},
#   {'id': 4782,
#    'identifier': 'dans-2c3-22d7',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2c3-22d7',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-09-15',
#    'storageIdentifier': 'surf://10.17026/dans-2c3-22d7',
#    'type': 'dataset'},
#   {'id': 4791,
#    'identifier': 'dans-xyr-fz9g',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xyr-fz9g',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-03',
#    'storageIdentifier': 'surf://10.17026/dans-xyr-fz9g',
#    'type': 'dataset'},
#   {'id': 4794,
#    'identifier': 'dans-297-hrgn',
#    'persistentUrl': 'https://doi.org/10.17026/dans-297-hrgn',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-10-03',
#    'storageIdentifier': 'surf://10.17026/dans-297-hrgn',
#    'type': 'dataset'},
#   {'id': 4803,
#    'identifier': 'dans-xfy-4en6',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xfy-4en6',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2016-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-xfy-4en6',
#    'type': 'dataset'},
#   {'id': 4806,
#    'identifier': 'dans-z9u-vv3g',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z9u-vv3g',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2016-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-z9u-vv3g',
#    'type': 'dataset'},
#   {'id': 4821,
#    'identifier': 'dans-23y-szwf',
#    'persistentUrl': 'https://doi.org/10.17026/dans-23y-szwf',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-22',
#    'storageIdentifier': 'surf://10.17026/dans-23y-szwf',
#    'type': 'dataset'},
#   {'id': 4827,
#    'identifier': 'dans-za3-7xn2',
#    'persistentUrl': 'https://doi.org/10.17026/dans-za3-7xn2',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-08-10',
#    'storageIdentifier': 'surf://10.17026/dans-za3-7xn2',
#    'type': 'dataset'},
#   {'id': 4828,
#    'identifier': 'dans-xsj-gzux',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xsj-gzux',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-22',
#    'storageIdentifier': 'surf://10.17026/dans-xsj-gzux',
#    'type': 'dataset'},
#   {'id': 4839,
#    'identifier': 'dans-x4w-dajr',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x4w-dajr',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-22',
#    'storageIdentifier': 'surf://10.17026/dans-x4w-dajr',
#    'type': 'dataset'},
#   {'id': 4840,
#    'identifier': 'dans-25d-cbap',
#    'persistentUrl': 'https://doi.org/10.17026/dans-25d-cbap',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1995-07-01',
#    'storageIdentifier': 'surf://10.17026/dans-25d-cbap',
#    'type': 'dataset'},
#   {'id': 4855,
#    'identifier': 'dans-zs3-ha7a',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zs3-ha7a',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-01-19',
#    'storageIdentifier': 'surf://10.17026/dans-zs3-ha7a',
#    'type': 'dataset'},
#   {'id': 4872,
#    'identifier': 'dans-25p-xv9b',
#    'persistentUrl': 'https://doi.org/10.17026/dans-25p-xv9b',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-29',
#    'storageIdentifier': 'surf://10.17026/dans-25p-xv9b',
#    'type': 'dataset'},
#   {'id': 4897,
#    'identifier': 'dans-zvj-n8ya',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zvj-n8ya',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-06-29',
#    'storageIdentifier': 'surf://10.17026/dans-zvj-n8ya',
#    'type': 'dataset'},
#   {'id': 4898,
#    'identifier': 'dans-27r-stdq',
#    'persistentUrl': 'https://doi.org/10.17026/dans-27r-stdq',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2017-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-27r-stdq',
#    'type': 'dataset'},
#   {'id': 4917,
#    'identifier': 'dans-z3y-676w',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z3y-676w',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2015-07-28',
#    'storageIdentifier': 'surf://10.17026/dans-z3y-676w',
#    'type': 'dataset'},
#   {'id': 4923,
#    'identifier': 'dans-zgh-qy55',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zgh-qy55',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-06',
#    'storageIdentifier': 'surf://10.17026/dans-zgh-qy55',
#    'type': 'dataset'},
#   {'id': 4929,
#    'identifier': 'dans-xuk-p42w',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xuk-p42w',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1950-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-xuk-p42w',
#    'type': 'dataset'},
#   {'id': 4941,
#    'identifier': 'dans-286-vsez',
#    'persistentUrl': 'https://doi.org/10.17026/dans-286-vsez',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1997-11-01',
#    'storageIdentifier': 'surf://10.17026/dans-286-vsez',
#    'type': 'dataset'},
#   {'id': 4955,
#    'identifier': 'dans-xxr-4sug',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xxr-4sug',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-23',
#    'storageIdentifier': 'surf://10.17026/dans-xxr-4sug',
#    'type': 'dataset'},
#   {'id': 4985,
#    'identifier': 'dans-xqn-4cdc',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xqn-4cdc',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-30',
#    'storageIdentifier': 'surf://10.17026/dans-xqn-4cdc',
#    'type': 'dataset'},
#   {'id': 5002,
#    'identifier': 'dans-zkz-9yzm',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zkz-9yzm',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-10',
#    'storageIdentifier': 'surf://10.17026/dans-zkz-9yzm',
#    'type': 'dataset'},
#   {'id': 5010,
#    'identifier': 'dans-zg6-zpw5',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zg6-zpw5',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-10',
#    'storageIdentifier': 'surf://10.17026/dans-zg6-zpw5',
#    'type': 'dataset'},
#   {'id': 5017,
#    'identifier': 'dans-xkk-brsa',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xkk-brsa',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-10',
#    'storageIdentifier': 'surf://10.17026/dans-xkk-brsa',
#    'type': 'dataset'},
#   {'id': 5023,
#    'identifier': 'dans-23u-7vby',
#    'persistentUrl': 'https://doi.org/10.17026/dans-23u-7vby',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-07-10',
#    'storageIdentifier': 'surf://10.17026/dans-23u-7vby',
#    'type': 'dataset'},
#   {'id': 5026,
# ...
#    'type': 'dataset'},
#   {'id': 29409,
#    'identifier': 'dans-xtr-578f',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xtr-578f',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-07-07',
#    'storageIdentifier': 'surf://10.17026/dans-xtr-578f',
#    'type': 'dataset'},
#   {'id': 29456,
#    'identifier': 'dans-xu6-z45w',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xu6-z45w',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-07-11',
#    'storageIdentifier': 'surf://10.17026/dans-xu6-z45w',
#    'type': 'dataset'},
#   {'id': 29469,
#    'identifier': 'dans-z99-5a7j',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z99-5a7j',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-08-15',
#    'storageIdentifier': 'surf://10.17026/dans-z99-5a7j',
#    'type': 'dataset'},
#   {'id': 29498,
#    'identifier': 'dans-xh2-tfbg',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xh2-tfbg',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-08-04',
#    'storageIdentifier': 'surf://10.17026/dans-xh2-tfbg',
#    'type': 'dataset'},
#   {'id': 29502,
#    'identifier': 'dans-2c7-wksz',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2c7-wksz',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-07-25',
#    'storageIdentifier': 'surf://10.17026/dans-2c7-wksz',
#    'type': 'dataset'},
#   {'id': 29511,
#    'identifier': 'dans-xnn-x5p3',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xnn-x5p3',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-08-30',
#    'storageIdentifier': 'surf://10.17026/dans-xnn-x5p3',
#    'type': 'dataset'},
#   {'id': 29525,
#    'identifier': 'dans-xj9-z365',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xj9-z365',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2014-08-31',
#    'storageIdentifier': 'surf://10.17026/dans-xj9-z365',
#    'type': 'dataset'},
#   {'id': 29539,
#    'identifier': 'dans-xwz-udxh',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xwz-udxh',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-11-30',
#    'storageIdentifier': 'surf://10.17026/dans-xwz-udxh',
#    'type': 'dataset'},
#   {'id': 29586,
#    'identifier': 'dans-xhn-ke54',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xhn-ke54',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-07-20',
#    'storageIdentifier': 'surf://10.17026/dans-xhn-ke54',
#    'type': 'dataset'},
#   {'id': 29667,
#    'identifier': 'dans-27y-s77z',
#    'persistentUrl': 'https://doi.org/10.17026/dans-27y-s77z',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-08-26',
#    'storageIdentifier': 'surf://10.17026/dans-27y-s77z',
#    'type': 'dataset'},
#   {'id': 29719,
#    'identifier': 'dans-zbb-xp6h',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zbb-xp6h',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2019-07-01',
#    'storageIdentifier': 'surf://10.17026/dans-zbb-xp6h',
#    'type': 'dataset'},
#   {'id': 29730,
#    'identifier': 'dans-23d-kmnc',
#    'persistentUrl': 'https://doi.org/10.17026/dans-23d-kmnc',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-13',
#    'storageIdentifier': 'surf://10.17026/dans-23d-kmnc',
#    'type': 'dataset'},
#   {'id': 29757,
#    'identifier': 'dans-xkv-3fkb',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xkv-3fkb',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-10-29',
#    'storageIdentifier': 'surf://10.17026/dans-xkv-3fkb',
#    'type': 'dataset'},
#   {'id': 29764,
#    'identifier': 'dans-xg5-cw67',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xg5-cw67',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-08-15',
#    'storageIdentifier': 'surf://10.17026/dans-xg5-cw67',
#    'type': 'dataset'},
#   {'id': 29868,
#    'identifier': 'dans-zhs-fewk',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zhs-fewk',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-08-30',
#    'storageIdentifier': 'surf://10.17026/dans-zhs-fewk',
#    'type': 'dataset'},
#   {'id': 29875,
#    'identifier': 'dans-xbm-gjk7',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xbm-gjk7',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-08-30',
#    'storageIdentifier': 'surf://10.17026/dans-xbm-gjk7',
#    'type': 'dataset'},
#   {'id': 29880,
#    'identifier': 'dans-2ay-9avv',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2ay-9avv',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-01-01',
#    'storageIdentifier': 'surf://10.17026/dans-2ay-9avv',
#    'type': 'dataset'},
#   {'id': 29884,
#    'identifier': 'dans-z8r-672p',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z8r-672p',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '1995-10-01',
#    'storageIdentifier': 'surf://10.17026/dans-z8r-672p',
#    'type': 'dataset'},
#   {'id': 29899,
#    'identifier': 'dans-zd9-q966',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zd9-q966',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2019-03-07',
#    'storageIdentifier': 'surf://10.17026/dans-zd9-q966',
#    'type': 'dataset'},
#   {'id': 29903,
#    'identifier': 'dans-xut-bxa8',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xut-bxa8',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2018-03-16',
#    'storageIdentifier': 'surf://10.17026/dans-xut-bxa8',
#    'type': 'dataset'},
#   {'id': 29910,
#    'identifier': 'dans-zn7-86wd',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zn7-86wd',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2019-06-17',
#    'storageIdentifier': 'surf://10.17026/dans-zn7-86wd',
#    'type': 'dataset'},
#   {'id': 29917,
#    'identifier': 'dans-zx9-fhqa',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zx9-fhqa',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2020-10-22',
#    'storageIdentifier': 'surf://10.17026/dans-zx9-fhqa',
#    'type': 'dataset'},
#   {'id': 29924,
#    'identifier': 'dans-z38-x3br',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z38-x3br',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2020-03-31',
#    'storageIdentifier': 'surf://10.17026/dans-z38-x3br',
#    'type': 'dataset'},
#   {'id': 29933,
#    'identifier': 'dans-z4p-zcud',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z4p-zcud',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2021-04-21',
#    'storageIdentifier': 'surf://10.17026/dans-z4p-zcud',
#    'type': 'dataset'},
#   {'id': 29943,
#    'identifier': 'dans-zat-xrpx',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zat-xrpx',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2019-03-26',
#    'storageIdentifier': 'surf://10.17026/dans-zat-xrpx',
#    'type': 'dataset'},
#   {'id': 29953,
#    'identifier': 'dans-xuq-ve6a',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xuq-ve6a',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2021-03-02',
#    'storageIdentifier': 'surf://10.17026/dans-xuq-ve6a',
#    'type': 'dataset'},
#   {'id': 29963,
#    'identifier': 'dans-z5q-d3ae',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z5q-d3ae',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-13',
#    'storageIdentifier': 'surf://10.17026/dans-z5q-d3ae',
#    'type': 'dataset'},
#   {'id': 29968,
#    'identifier': 'dans-27g-bypr',
#    'persistentUrl': 'https://doi.org/10.17026/dans-27g-bypr',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-13',
#    'storageIdentifier': 'surf://10.17026/dans-27g-bypr',
#    'type': 'dataset'},
#   {'id': 29976,
#    'identifier': 'dans-zqq-x46g',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zqq-x46g',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-20',
#    'storageIdentifier': 'surf://10.17026/dans-zqq-x46g',
#    'type': 'dataset'},
#   {'id': 29979,
#    'identifier': 'dans-ztj-hguk',
#    'persistentUrl': 'https://doi.org/10.17026/dans-ztj-hguk',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-15',
#    'storageIdentifier': 'surf://10.17026/dans-ztj-hguk',
#    'type': 'dataset'},
#   {'id': 29982,
#    'identifier': 'dans-2xy-8u3w',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2xy-8u3w',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-13',
#    'storageIdentifier': 'surf://10.17026/dans-2xy-8u3w',
#    'type': 'dataset'},
#   {'id': 29986,
#    'identifier': 'dans-zbe-wk2h',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zbe-wk2h',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2019-08-01',
#    'storageIdentifier': 'surf://10.17026/dans-zbe-wk2h',
#    'type': 'dataset'},
#   {'id': 29990,
#    'identifier': 'dans-zff-n7g6',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zff-n7g6',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2019-06-30',
#    'storageIdentifier': 'surf://10.17026/dans-zff-n7g6',
#    'type': 'dataset'},
#   {'id': 30000,
#    'identifier': 'dans-zrs-fx7c',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zrs-fx7c',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2021-05-31',
#    'storageIdentifier': 'surf://10.17026/dans-zrs-fx7c',
#    'type': 'dataset'},
#   {'id': 30058,
#    'identifier': 'dans-2xk-qkns',
#    'persistentUrl': 'https://doi.org/10.17026/dans-2xk-qkns',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-15',
#    'storageIdentifier': 'surf://10.17026/dans-2xk-qkns',
#    'type': 'dataset'},
#   {'id': 30068,
#    'identifier': 'dans-24t-2tts',
#    'persistentUrl': 'https://doi.org/10.17026/dans-24t-2tts',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-15',
#    'storageIdentifier': 'surf://10.17026/dans-24t-2tts',
#    'type': 'dataset'},
#   {'id': 30075,
#    'identifier': 'dans-z9b-7fej',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z9b-7fej',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2020-12-20',
#    'storageIdentifier': 'surf://10.17026/dans-z9b-7fej',
#    'type': 'dataset'},
#   {'id': 30082,
#    'identifier': 'dans-z3y-vwsw',
#    'persistentUrl': 'https://doi.org/10.17026/dans-z3y-vwsw',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-20',
#    'storageIdentifier': 'surf://10.17026/dans-z3y-vwsw',
#    'type': 'dataset'},
#   {'id': 30090,
#    'identifier': 'dans-29k-dwd8',
#    'persistentUrl': 'https://doi.org/10.17026/dans-29k-dwd8',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-20',
#    'storageIdentifier': 'surf://10.17026/dans-29k-dwd8',
#    'type': 'dataset'},
#   {'id': 30101,
#    'identifier': 'dans-22h-8zw5',
#    'persistentUrl': 'https://doi.org/10.17026/dans-22h-8zw5',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-26',
#    'storageIdentifier': 'surf://10.17026/dans-22h-8zw5',
#    'type': 'dataset'},
#   {'id': 30103,
#    'identifier': 'dans-zy7-2p8x',
#    'persistentUrl': 'https://doi.org/10.17026/dans-zy7-2p8x',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-20',
#    'storageIdentifier': 'surf://10.17026/dans-zy7-2p8x',
#    'type': 'dataset'},
#   {'id': 30107,
#    'identifier': 'dans-xgq-6kts',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xgq-6kts',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2020-11-26',
#    'storageIdentifier': 'surf://10.17026/dans-xgq-6kts',
#    'type': 'dataset'},
#   {'id': 30109,
#    'identifier': 'dans-274-ks3p',
#    'persistentUrl': 'https://doi.org/10.17026/dans-274-ks3p',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2021-04-12',
#    'storageIdentifier': 'surf://10.17026/dans-274-ks3p',
#    'type': 'dataset'},
#   {'id': 30113,
#    'identifier': 'dans-x8f-v2yx',
#    'persistentUrl': 'https://doi.org/10.17026/dans-x8f-v2yx',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2022-09-20',
#    'storageIdentifier': 'surf://10.17026/dans-x8f-v2yx',
#    'type': 'dataset'},
#   {'id': 30114,
#    'identifier': 'dans-xwe-2xsb',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xwe-2xsb',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2021-01-26',
#    'storageIdentifier': 'surf://10.17026/dans-xwe-2xsb',
#    'type': 'dataset'},
#   {'id': 30119,
#    'identifier': 'dans-xhm-w5rm',
#    'persistentUrl': 'https://doi.org/10.17026/dans-xhm-w5rm',
#    'protocol': 'doi',
#    'authority': '10.17026',
#    'publisher': 'DANS Data Station Social Sciences and Humanities',
#    'publicationDate': '2021-01-20',
#    'storageIdentifier': 'surf://10.17026/dans-xhm-w5rm',
#    'type': 'dataset'},
#   ...]}

# %% [markdown]
# Save it here so we don't have to do the above again

# %%
with open("dans.json", "wb") as f:
    f.write(tree.read())

# %% [markdown]
# Move the data into pandas to start working with it

# %%
df_dans = pd.DataFrame.from_dict(tree.json()["data"])

df_dans
# Out:
#           id     identifier                           persistentUrl protocol  \
# 0       1920  dans-zhr-eswk  https://doi.org/10.17026/dans-zhr-eswk      doi
# 1       1921  dans-xeh-f6xm  https://doi.org/10.17026/dans-xeh-f6xm      doi
# 2       1924  dans-zct-en83  https://doi.org/10.17026/dans-zct-en83      doi
# 3       1949  dans-xjk-kqxa  https://doi.org/10.17026/dans-xjk-kqxa      doi
# 4       2082  dans-xpa-uek9  https://doi.org/10.17026/dans-xpa-uek9      doi
# ...      ...            ...                                     ...      ...
# 8687  615257      SS/GIJTA1      https://doi.org/10.17026/SS/GIJTA1      doi
# 8688  615280      SS/IHYCRX      https://doi.org/10.17026/SS/IHYCRX      doi
# 8689  615286      SS/ZY6QIP      https://doi.org/10.17026/SS/ZY6QIP      doi
# 8690  615288      SS/TM4SW5      https://doi.org/10.17026/SS/TM4SW5      doi
# 8691  615381      SS/APJCF3      https://doi.org/10.17026/SS/APJCF3      doi
#
#      authority                                         publisher  \
# 0     10.17026  DANS Data Station Social Sciences and Humanities
# 1     10.17026  DANS Data Station Social Sciences and Humanities
# 2     10.17026  DANS Data Station Social Sciences and Humanities
# 3     10.17026  DANS Data Station Social Sciences and Humanities
# 4     10.17026  DANS Data Station Social Sciences and Humanities
# ...        ...                                               ...
# 8687  10.17026  DANS Data Station Social Sciences and Humanities
# 8688  10.17026  DANS Data Station Social Sciences and Humanities
# 8689  10.17026  DANS Data Station Social Sciences and Humanities
# 8690  10.17026  DANS Data Station Social Sciences and Humanities
# 8691  10.17026  DANS Data Station Social Sciences and Humanities
#
#      publicationDate              storageIdentifier     type
# 0         1990-01-01  surf://10.17026/dans-zhr-eswk  dataset
# 1         1995-01-01  surf://10.17026/dans-xeh-f6xm  dataset
# 2         1999-01-01  surf://10.17026/dans-zct-en83  dataset
# 3         2004-01-01  surf://10.17026/dans-xjk-kqxa  dataset
# 4         1993-01-01  surf://10.17026/dans-xpa-uek9  dataset
# ...              ...                            ...      ...
# 8687      2025-05-28      surf://10.17026/SS/GIJTA1  dataset
# 8688      2025-05-13      surf://10.17026/SS/IHYCRX  dataset
# 8689      2025-05-12      surf://10.17026/SS/ZY6QIP  dataset
# 8690      2025-05-09      surf://10.17026/SS/TM4SW5  dataset
# 8691      2025-05-16      surf://10.17026/SS/APJCF3  dataset
#
# [8692 rows x 9 columns]

# %%
df_dans.sample(5)["persistentUrl"]
# Out:
# 6898    https://doi.org/10.17026/dans-xa6-6gpf
# 696     https://doi.org/10.17026/dans-2ca-hxmd
# 1540    https://doi.org/10.17026/dans-zkw-e99f
# 1431    https://doi.org/10.17026/dans-z4j-yrfe
# 6605    https://doi.org/10.17026/dans-z8w-wqqs
# Name: persistentUrl, dtype: object

# %%
def fair_checker(pid: str):
    res = r.get("https://fair-checker.france-bioinformatique.fr/api/check/legacy/metrics_all", params={"url": pid})
    return {metric["metric"]: int(metric["score"]) for metric in res.json()}

# %%
sample = df_dans.sample(2)["persistentUrl"]
results: pd.DataFrame = sample.apply(fair_checker).apply(pd.Series) / 2

pd.concat([sample, results], axis=1)
# Out:
#                                persistentUrl  F1A  F1B  F2A  F2B  A1.1  A1.2  \
# 232   https://doi.org/10.17026/dans-279-hy72  1.0  1.0  0.5  0.5   1.0   1.0
# 1625  https://doi.org/10.17026/dans-xqf-78qs  1.0  1.0  0.5  0.5   1.0   1.0
#
#        I1   I2   I3  R1.1  R1.2  R1.3
# 232   0.5  0.5  1.0   1.0   1.0   0.5
# 1625  0.5  0.5  1.0   1.0   1.0   0.5

# %%
results.to_latex()
# Out:
# '\\begin{tabular}{lrrrrrrrrrrrr}\n\\toprule\n & F1A & F1B & F2A & F2B & A1.1 & A1.2 & I1 & I2 & I3 & R1.1 & R1.2 & R1.3 \\\\\n\\midrule\n232 & 1.000000 & 1.000000 & 0.500000 & 0.500000 & 1.000000 & 1.000000 & 0.500000 & 0.500000 & 1.000000 & 1.000000 & 1.000000 & 0.500000 \\\\\n1625 & 1.000000 & 1.000000 & 0.500000 & 0.500000 & 1.000000 & 1.000000 & 0.500000 & 0.500000 & 1.000000 & 1.000000 & 1.000000 & 0.500000 \\\\\n\\bottomrule\n\\end{tabular}\n'
